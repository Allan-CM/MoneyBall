# %%
# importing Dependencies
import requests
import json
import pandas as pd

# %%
# Define API endpoints and headers
teams_url = "https://api-football-v1.p.rapidapi.com/v3/teams"
stats_url = "https://api-football-v1.p.rapidapi.com/v3/coachs"
headers = {
    "X-RapidAPI-Key": "e745f20ff6mshb3a174087c1d159p11ee9ejsn4221f696691e",
    "X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

# Define the range of seasons
start_season = 2019
end_season = 2024
league_id = "371"  # Example league ID

# Initialize an empty list to hold all team IDs
all_team_ids = []

# Function to fetch teams for a given season and add their IDs to all_team_ids
def fetch_teams_for_season(season):
    querystring = {"league": league_id, "season": str(season)}
    response = requests.get(teams_url, headers=headers, params=querystring)
    
    if response.status_code == 200:
        data = response.json()
        for team in data['response']:
            team_id = team['team']['id']
            if team_id not in all_team_ids:
                all_team_ids.append(team_id)
    else:
        print(f"Failed to fetch teams for season {season}: {response.status_code}")

# Fetch teams for all seasons
for year in range(start_season, end_season):
    fetch_teams_for_season(year)

# Initialize a list to hold all coach data
all_coach_data = []

# Function to fetch statistics for a given team and season
def fetch_coach_statistics(team_id):
    querystring = {"team": str(team_id)}
    response = requests.get(stats_url, headers=headers, params=querystring)
    
    if response.status_code == 200:
        data = response.json()
        all_coach_data.append(data)
    else:
        print(f"Failed to fetch stats for team {team_id}: {response.status_code}")

# Fetch statistics for all teams in all seasons
for team_id in all_team_ids:
    fetch_coach_statistics(team_id)

# Print the aggregated statistics data in a formatted way
print(json.dumps(all_coach_data, indent=4))
# Out:
# [
#     {
#         "get": "coachs",
#         "parameters": {
#             "team": "574"
#         },
#         "errors": [],
#         "results": 5,
#         "paging": {
#             "current": 1,
#             "total": 1
#         },
#         "response": [
#             {
#                 "id": 1833,
#                 "name": "G. Mihajlov",
#                 "firstname": "Gorazd",
#                 "lastname": "Mihajlov",
#                 "age": 51,
#                 "birth": {
#                     "date": "1973-08-21",
#                     "place": null,
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": null,
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/1833.png",
#                 "team": {
#                     "id": 574,
#                     "name": "Vardar Skopje",
#                     "logo": "https://media.api-sports.io/football/teams/574.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 574,
#                             "name": "Vardar Skopje",
#                             "logo": "https://media.api-sports.io/football/teams/574.png"
#                         },
#                         "start": "2023-12-01",
#                         "end": null
#                     },
#                     {
#                         "team": {
#                             "id": 4331,
#                             "name": "Sileks",
#                             "logo": "https://media.api-sports.io/football/teams/4331.png"
#                         },
#                         "start": "2021-06-01",
#                         "end": "2023-12-01"
#                     },
#                     {
#                         "team": {
#                             "id": 4334,
#                             "name": "Borec Veles",
#                             "logo": "https://media.api-sports.io/football/teams/4334.png"
#                         },
#                         "start": "2018-07-01",
#                         "end": "2021-01-01"
#                     },
#                     {
#                         "team": {
#                             "id": 4347,
#                             "name": "Teteks",
#                             "logo": "https://media.api-sports.io/football/teams/4347.png"
#                         },
#                         "start": "2015-01-01",
#                         "end": "2016-06-01"
#                     },
#                     {
#                         "team": {
#                             "id": null,
#                             "name": "Napredok",
#                             "logo": null
#                         },
#                         "start": "2013-08-01",
#                         "end": "2014-01-01"
#                     },
#                     {
#                         "team": {
#                             "id": 4347,
#                             "name": "Teteks",
#                             "logo": "https://media.api-sports.io/football/teams/4347.png"
#                         },
#                         "start": "2013-03-01",
#                         "end": "2013-06-01"
#                     },
#                     {
#                         "team": {
#                             "id": 693,
#                             "name": "Pelister",
#                             "logo": "https://media.api-sports.io/football/teams/693.png"
#                         },
#                         "start": "2012-07-01",
#                         "end": "2012-11-01"
#                     },
#                     {
#                         "team": {
#                             "id": 6290,
#                             "name": "Ohrid Lihnidos",
#                             "logo": "https://media.api-sports.io/football/teams/6290.png"
#                         },
#                         "start": "2012-01-01",
#                         "end": "2012-04-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 4247,
#                 "name": "G. Hadzhievski",
#                 "firstname": "Gjoko",
#                 "lastname": "Hadzhievski",
#                 "age": 69,
#                 "birth": {
#                     "date": "1955-03-31",
#                     "place": null,
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": null,
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/4247.png",
#                 "team": {
#                     "id": 574,
#                     "name": "Vardar Skopje",
#                     "logo": "https://media.api-sports.io/football/teams/574.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 574,
#                             "name": "Vardar Skopje",
#                             "logo": "https://media.api-sports.io/football/teams/574.png"
#                         },
#                         "start": "2023-08-01",
#                         "end": "2023-08-01"
#                     },
#                     {
#                         "team": {
#                             "id": 4328,
#                             "name": "Belasica",
#                             "logo": "https://media.api-sports.io/football/teams/4328.png"
#                         },
#                         "start": "2019-03-01",
#                         "end": "2019-04-01"
#                     },
#                     {
#                         "team": {
#                             "id": 2873,
#                             "name": "Al Dhafra",
#                             "logo": "https://media.api-sports.io/football/teams/2873.png"
#                         },
#                         "start": "2018-01-01",
#                         "end": "2018-08-01"
#                     },
#                     {
#                         "team": {
#                             "id": 2869,
#                             "name": "Hatta",
#                             "logo": "https://media.api-sports.io/football/teams/2869.png"
#                         },
#                         "start": "2016-10-01",
#                         "end": "2017-10-01"
#                     },
#                     {
#                         "team": {
#                             "id": 693,
#                             "name": "Pelister",
#                             "logo": "https://media.api-sports.io/football/teams/693.png"
#                         },
#                         "start": "2014-12-01",
#                         "end": "2015-06-01"
#                     },
#                     {
#                         "team": {
#                             "id": 2933,
#                             "name": "Al-Qadsiah",
#                             "logo": "https://media.api-sports.io/football/teams/2933.png"
#                         },
#                         "start": "2014-02-01",
#                         "end": "2014-11-01"
#                     },
#                     {
#                         "team": {
#                             "id": 2927,
#                             "name": "Najran",
#                             "logo": "https://media.api-sports.io/football/teams/2927.png"
#                         },
#                         "start": "2013-03-01",
#                         "end": "2014-01-01"
#                     },
#                     {
#                         "team": {
#                             "id": 2936,
#                             "name": "Al-Taawoun",
#                             "logo": "https://media.api-sports.io/football/teams/2936.png"
#                         },
#                         "start": "2012-06-01",
#                         "end": "2013-02-01"
#                     },
#                     {
#                         "team": {
#                             "id": 2927,
#                             "name": "Najran",
#                             "logo": "https://media.api-sports.io/football/teams/2927.png"
#                         },
#                         "start": "2011-07-01",
#                         "end": "2012-06-01"
#                     },
#                     {
#                         "team": {
#                             "id": 11245,
#                             "name": "Simurq",
#                             "logo": "https://media.api-sports.io/football/teams/11245.png"
#                         },
#                         "start": "2010-08-01",
#                         "end": "2011-06-01"
#                     },
#                     {
#                         "team": {
#                             "id": 1096,
#                             "name": "Azerbaijan",
#                             "logo": "https://media.api-sports.io/football/teams/1096.png"
#                         },
#                         "start": "2007-11-01",
#                         "end": "2008-02-01"
#                     },
#                     {
#                         "team": {
#                             "id": 11233,
#                             "name": "Bak\u0131",
#                             "logo": "https://media.api-sports.io/football/teams/11233.png"
#                         },
#                         "start": "2007-07-01",
#                         "end": "2010-09-01"
#                     },
#                     {
#                         "team": {
#                             "id": 1105,
#                             "name": "North Macedonia",
#                             "logo": "https://media.api-sports.io/football/teams/1105.png"
#                         },
#                         "start": "1996-01-01",
#                         "end": "1999-08-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 4610,
#                 "name": "N. Ilievski",
#                 "firstname": "Nikola",
#                 "lastname": "Ilievski",
#                 "age": 70,
#                 "birth": {
#                     "date": "1954-12-16",
#                     "place": "Skopje",
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": null,
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/4610.png",
#                 "team": {
#                     "id": 574,
#                     "name": "Vardar Skopje",
#                     "logo": "https://media.api-sports.io/football/teams/574.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 574,
#                             "name": "Vardar Skopje",
#                             "logo": "https://media.api-sports.io/football/teams/574.png"
#                         },
#                         "start": "2021-02-01",
#                         "end": "2021-06-01"
#                     },
#                     {
#                         "team": {
#                             "id": 4330,
#                             "name": "Renova",
#                             "logo": "https://media.api-sports.io/football/teams/4330.png"
#                         },
#                         "start": "2018-10-01",
#                         "end": "2019-06-01"
#                     },
#                     {
#                         "team": {
#                             "id": 574,
#                             "name": "Vardar Skopje",
#                             "logo": "https://media.api-sports.io/football/teams/574.png"
#                         },
#                         "start": "2013-01-01",
#                         "end": "2013-04-01"
#                     },
#                     {
#                         "team": {
#                             "id": 1560,
#                             "name": "Bangladesh",
#                             "logo": "https://media.api-sports.io/football/teams/1560.png"
#                         },
#                         "start": "2011-06-01",
#                         "end": "2011-12-01"
#                     },
#                     {
#                         "team": {
#                             "id": 3325,
#                             "name": "Bylis",
#                             "logo": "https://media.api-sports.io/football/teams/3325.png"
#                         },
#                         "start": "2010-09-01",
#                         "end": "2011-03-01"
#                     },
#                     {
#                         "team": {
#                             "id": 1105,
#                             "name": "North Macedonia",
#                             "logo": "https://media.api-sports.io/football/teams/1105.png"
#                         },
#                         "start": "2002-02-01",
#                         "end": "2003-06-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 16401,
#                 "name": "N. Gligorov",
#                 "firstname": "Nikola",
#                 "lastname": "Gligorov",
#                 "age": 41,
#                 "birth": {
#                     "date": "1983-08-15",
#                     "place": "Skopje",
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": "178 cm",
#                 "weight": "75 kg",
#                 "photo": "https://media.api-sports.io/football/coachs/16401.png",
#                 "team": {
#                     "id": 574,
#                     "name": "Vardar Skopje",
#                     "logo": "https://media.api-sports.io/football/teams/574.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 574,
#                             "name": "Vardar Skopje",
#                             "logo": "https://media.api-sports.io/football/teams/574.png"
#                         },
#                         "start": "2021-09-01",
#                         "end": "2022-04-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 18923,
#                 "name": "B. Grncharov",
#                 "firstname": "Boban",
#                 "lastname": "Grncharov",
#                 "age": 42,
#                 "birth": {
#                     "date": "1982-08-12",
#                     "place": "Skopje",
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": "193 cm",
#                 "weight": "89 kg",
#                 "photo": "https://media.api-sports.io/football/coachs/18923.png",
#                 "team": {
#                     "id": 574,
#                     "name": "Vardar Skopje",
#                     "logo": "https://media.api-sports.io/football/teams/574.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 574,
#                             "name": "Vardar Skopje",
#                             "logo": "https://media.api-sports.io/football/teams/574.png"
#                         },
#                         "start": "2022-04-01",
#                         "end": "2023-08-01"
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "get": "coachs",
#         "parameters": {
#             "team": "609"
#         },
#         "errors": [],
#         "results": 4,
#         "paging": {
#             "current": 1,
#             "total": 1
#         },
#         "response": [
#             {
#                 "id": 1837,
#                 "name": "J. Beqiri",
#                 "firstname": "Jeton",
#                 "lastname": "Bekjiri",
#                 "age": 42,
#                 "birth": {
#                     "date": "1982-06-12",
#                     "place": "Tetovo",
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": null,
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/1837.png",
#                 "team": {
#                     "id": 609,
#                     "name": "Shkendija",
#                     "logo": "https://media.api-sports.io/football/teams/609.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 609,
#                             "name": "Shkendija",
#                             "logo": "https://media.api-sports.io/football/teams/609.png"
#                         },
#                         "start": "2024-01-01",
#                         "end": null
#                     },
#                     {
#                         "team": {
#                             "id": 3325,
#                             "name": "Bylis",
#                             "logo": "https://media.api-sports.io/football/teams/3325.png"
#                         },
#                         "start": "2021-07-01",
#                         "end": "2022-08-01"
#                     },
#                     {
#                         "team": {
#                             "id": 4346,
#                             "name": "Struga",
#                             "logo": "https://media.api-sports.io/football/teams/4346.png"
#                         },
#                         "start": "2019-07-01",
#                         "end": "2020-03-01"
#                     },
#                     {
#                         "team": {
#                             "id": 4330,
#                             "name": "Renova",
#                             "logo": "https://media.api-sports.io/football/teams/4330.png"
#                         },
#                         "start": "2018-06-01",
#                         "end": "2018-09-01"
#                     },
#                     {
#                         "team": {
#                             "id": 609,
#                             "name": "Shkendija",
#                             "logo": "https://media.api-sports.io/football/teams/609.png"
#                         },
#                         "start": "2016-10-01",
#                         "end": "2016-12-01"
#                     },
#                     {
#                         "team": {
#                             "id": 609,
#                             "name": "Shkendija",
#                             "logo": "https://media.api-sports.io/football/teams/609.png"
#                         },
#                         "start": "2015-03-01",
#                         "end": "2015-06-01"
#                     },
#                     {
#                         "team": {
#                             "id": 2248,
#                             "name": "Drita",
#                             "logo": "https://media.api-sports.io/football/teams/2248.png"
#                         },
#                         "start": "2013-04-01",
#                         "end": "2014-12-01"
#                     },
#                     {
#                         "team": {
#                             "id": 2248,
#                             "name": "Drita",
#                             "logo": "https://media.api-sports.io/football/teams/2248.png"
#                         },
#                         "start": "2012-07-01",
#                         "end": "2012-09-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 2641,
#                 "name": "E. Gjoka",
#                 "firstname": "Ernest",
#                 "lastname": "Gjoka",
#                 "age": 54,
#                 "birth": {
#                     "date": "1970-01-25",
#                     "place": "Tiran\u00eb",
#                     "country": "Albania"
#                 },
#                 "nationality": "Albania",
#                 "height": null,
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/2641.png",
#                 "team": {
#                     "id": 609,
#                     "name": "Shkendija",
#                     "logo": "https://media.api-sports.io/football/teams/609.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 609,
#                             "name": "Shkendija",
#                             "logo": "https://media.api-sports.io/football/teams/609.png"
#                         },
#                         "start": "2019-10-01",
#                         "end": "2021-07-01"
#                     },
#                     {
#                         "team": {
#                             "id": 577,
#                             "name": "Kuk\u00ebsi",
#                             "logo": "https://media.api-sports.io/football/teams/577.png"
#                         },
#                         "start": "2019-04-01",
#                         "end": "2019-07-01"
#                     },
#                     {
#                         "team": {
#                             "id": 3318,
#                             "name": "Kamza",
#                             "logo": "https://media.api-sports.io/football/teams/3318.png"
#                         },
#                         "start": "2018-11-01",
#                         "end": "2019-02-01"
#                     },
#                     {
#                         "team": {
#                             "id": 3339,
#                             "name": "Vllaznia Shkod\u00ebr",
#                             "logo": "https://media.api-sports.io/football/teams/3339.png"
#                         },
#                         "start": "2017-10-01",
#                         "end": "2018-05-01"
#                     },
#                     {
#                         "team": {
#                             "id": 577,
#                             "name": "Kuk\u00ebsi",
#                             "logo": "https://media.api-sports.io/football/teams/577.png"
#                         },
#                         "start": "2016-07-01",
#                         "end": "2017-07-01"
#                     },
#                     {
#                         "team": {
#                             "id": 3317,
#                             "name": "Flamurtari",
#                             "logo": "https://media.api-sports.io/football/teams/3317.png"
#                         },
#                         "start": "2012-12-01",
#                         "end": "2014-10-01"
#                     },
#                     {
#                         "team": {
#                             "id": 3321,
#                             "name": "Apolonia Fier",
#                             "logo": "https://media.api-sports.io/football/teams/3321.png"
#                         },
#                         "start": "2012-07-01",
#                         "end": "2012-10-01"
#                     },
#                     {
#                         "team": {
#                             "id": 3336,
#                             "name": "Tomori Berat",
#                             "logo": "https://media.api-sports.io/football/teams/3336.png"
#                         },
#                         "start": "2012-03-01",
#                         "end": "2012-06-01"
#                     },
#                     {
#                         "team": {
#                             "id": 3318,
#                             "name": "Kamza",
#                             "logo": "https://media.api-sports.io/football/teams/3318.png"
#                         },
#                         "start": "2011-07-01",
#                         "end": "2012-01-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 11645,
#                 "name": "A. Nuhiji",
#                 "firstname": "Ardijan",
#                 "lastname": "Nuhiji",
#                 "age": 46,
#                 "birth": {
#                     "date": "1978-07-12",
#                     "place": "Skopje",
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": "172 cm",
#                 "weight": "70 kg",
#                 "photo": "https://media.api-sports.io/football/coachs/11645.png",
#                 "team": {
#                     "id": 609,
#                     "name": "Shkendija",
#                     "logo": "https://media.api-sports.io/football/teams/609.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 609,
#                             "name": "Shkendija",
#                             "logo": "https://media.api-sports.io/football/teams/609.png"
#                         },
#                         "start": "2023-06-01",
#                         "end": "2023-12-01"
#                     },
#                     {
#                         "team": {
#                             "id": 14281,
#                             "name": "Drita",
#                             "logo": "https://media.api-sports.io/football/teams/14281.png"
#                         },
#                         "start": "2019-02-01",
#                         "end": "2022-11-01"
#                     },
#                     {
#                         "team": {
#                             "id": 2265,
#                             "name": "Shkupi",
#                             "logo": "https://media.api-sports.io/football/teams/2265.png"
#                         },
#                         "start": "2017-01-01",
#                         "end": "2018-03-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 11762,
#                 "name": "A. Shakiri",
#                 "firstname": "Artim",
#                 "lastname": "Shakiri",
#                 "age": 51,
#                 "birth": {
#                     "date": "1973-09-23",
#                     "place": "Skopje",
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": "180 cm",
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/11762.png",
#                 "team": {
#                     "id": 609,
#                     "name": "Shkendija",
#                     "logo": "https://media.api-sports.io/football/teams/609.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 609,
#                             "name": "Shkendija",
#                             "logo": "https://media.api-sports.io/football/teams/609.png"
#                         },
#                         "start": "2022-04-01",
#                         "end": "2022-09-01"
#                     },
#                     {
#                         "team": {
#                             "id": 2182,
#                             "name": "Schaffhausen",
#                             "logo": "https://media.api-sports.io/football/teams/2182.png"
#                         },
#                         "start": "2021-09-01",
#                         "end": "2021-09-01"
#                     },
#                     {
#                         "team": {
#                             "id": 14397,
#                             "name": "Flamurtari",
#                             "logo": "https://media.api-sports.io/football/teams/14397.png"
#                         },
#                         "start": "2019-06-01",
#                         "end": "2019-10-01"
#                     },
#                     {
#                         "team": {
#                             "id": 4606,
#                             "name": "Pembroke Athleta",
#                             "logo": "https://media.api-sports.io/football/teams/4606.png"
#                         },
#                         "start": "2016-10-01",
#                         "end": "2018-12-01"
#                     },
#                     {
#                         "team": {
#                             "id": 577,
#                             "name": "Kuk\u00ebsi",
#                             "logo": "https://media.api-sports.io/football/teams/577.png"
#                         },
#                         "start": "2014-08-01",
#                         "end": "2015-04-01"
#                     },
#                     {
#                         "team": {
#                             "id": 609,
#                             "name": "Shkendija",
#                             "logo": "https://media.api-sports.io/football/teams/609.png"
#                         },
#                         "start": "2012-08-01",
#                         "end": "2013-06-01"
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "get": "coachs",
#         "parameters": {
#             "team": "663"
#         },
#         "errors": [],
#         "results": 7,
#         "paging": {
#             "current": 1,
#             "total": 1
#         },
#         "response": [
#             {
#                 "id": 1830,
#                 "name": "A. Vlaho",
#                 "firstname": "Aleksandar",
#                 "lastname": "Vlaho",
#                 "age": 48,
#                 "birth": {
#                     "date": "1976-01-18",
#                     "place": null,
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": null,
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/1830.png",
#                 "team": {
#                     "id": 663,
#                     "name": "Rabotni\u010dki",
#                     "logo": "https://media.api-sports.io/football/teams/663.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 663,
#                             "name": "Rabotni\u010dki",
#                             "logo": "https://media.api-sports.io/football/teams/663.png"
#                         },
#                         "start": "2021-01-01",
#                         "end": "2021-11-01"
#                     },
#                     {
#                         "team": {
#                             "id": 663,
#                             "name": "Rabotni\u010dki",
#                             "logo": "https://media.api-sports.io/football/teams/663.png"
#                         },
#                         "start": "2019-07-01",
#                         "end": "2019-10-01"
#                     },
#                     {
#                         "team": {
#                             "id": 13840,
#                             "name": "Metalurg",
#                             "logo": "https://media.api-sports.io/football/teams/13840.png"
#                         },
#                         "start": "2012-07-01",
#                         "end": "2012-07-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 4416,
#                 "name": "G. Sedloski",
#                 "firstname": "Goce",
#                 "lastname": "Sedloski",
#                 "age": 50,
#                 "birth": {
#                     "date": "1974-04-10",
#                     "place": "Golemo Konjari",
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": "188 cm",
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/4416.png",
#                 "team": {
#                     "id": 663,
#                     "name": "Rabotni\u010dki",
#                     "logo": "https://media.api-sports.io/football/teams/663.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 663,
#                             "name": "Rabotni\u010dki",
#                             "logo": "https://media.api-sports.io/football/teams/663.png"
#                         },
#                         "start": "2023-11-01",
#                         "end": null
#                     },
#                     {
#                         "team": {
#                             "id": 3339,
#                             "name": "Vllaznia Shkod\u00ebr",
#                             "logo": "https://media.api-sports.io/football/teams/3339.png"
#                         },
#                         "start": "2023-04-01",
#                         "end": "2023-05-01"
#                     },
#                     {
#                         "team": {
#                             "id": 2265,
#                             "name": "Shkupi",
#                             "logo": "https://media.api-sports.io/football/teams/2265.png"
#                         },
#                         "start": "2022-09-01",
#                         "end": "2023-03-01"
#                     },
#                     {
#                         "team": {
#                             "id": 2265,
#                             "name": "Shkupi",
#                             "logo": "https://media.api-sports.io/football/teams/2265.png"
#                         },
#                         "start": "2021-04-01",
#                         "end": "2022-09-01"
#                     },
#                     {
#                         "team": {
#                             "id": 7896,
#                             "name": "Dinamo Zagreb U19",
#                             "logo": "https://media.api-sports.io/football/teams/7896.png"
#                         },
#                         "start": "2020-07-01",
#                         "end": "2020-10-01"
#                     },
#                     {
#                         "team": {
#                             "id": 1476,
#                             "name": "Dinamo Zagreb II",
#                             "logo": "https://media.api-sports.io/football/teams/1476.png"
#                         },
#                         "start": "2020-05-01",
#                         "end": "2020-10-01"
#                     },
#                     {
#                         "team": {
#                             "id": 642,
#                             "name": "Siroki Brijeg",
#                             "logo": "https://media.api-sports.io/football/teams/642.png"
#                         },
#                         "start": "2018-08-01",
#                         "end": "2019-07-01"
#                     },
#                     {
#                         "team": {
#                             "id": 10124,
#                             "name": "Riga",
#                             "logo": "https://media.api-sports.io/football/teams/10124.png"
#                         },
#                         "start": "2018-01-01",
#                         "end": "2018-05-01"
#                     },
#                     {
#                         "team": {
#                             "id": 574,
#                             "name": "Vardar Skopje",
#                             "logo": "https://media.api-sports.io/football/teams/574.png"
#                         },
#                         "start": "2015-07-01",
#                         "end": "2017-08-01"
#                     },
#                     {
#                         "team": {
#                             "id": 4356,
#                             "name": "Turnovo",
#                             "logo": "https://media.api-sports.io/football/teams/4356.png"
#                         },
#                         "start": "2013-09-01",
#                         "end": "2014-07-01"
#                     },
#                     {
#                         "team": {
#                             "id": 1105,
#                             "name": "North Macedonia",
#                             "logo": "https://media.api-sports.io/football/teams/1105.png"
#                         },
#                         "start": "2012-08-01",
#                         "end": "2012-08-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 8756,
#                 "name": "T. Franc",
#                 "firstname": "Tomislav",
#                 "lastname": "Franc",
#                 "age": 50,
#                 "birth": {
#                     "date": "1967-05-27",
#                     "place": null,
#                     "country": "FYR Macedonia"
#                 },
#                 "nationality": "FYR Macedonia",
#                 "height": null,
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/8756.png",
#                 "team": {
#                     "id": 663,
#                     "name": "Rabotni\u010dki",
#                     "logo": "https://media.api-sports.io/football/teams/663.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 663,
#                             "name": "Rabotni\u010dki",
#                             "logo": "https://media.api-sports.io/football/teams/663.png"
#                         },
#                         "start": "2015-06-16",
#                         "end": "2016-07-31"
#                     }
#                 ]
#             },
#             {
#                 "id": 11647,
#                 "name": "L. Markovski",
#                 "firstname": "Ljupcho",
#                 "lastname": "Markovski",
#                 "age": 57,
#                 "birth": {
#                     "date": "1967-02-24",
#                     "place": null,
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": null,
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/11647.png",
#                 "team": {
#                     "id": 663,
#                     "name": "Rabotni\u010dki",
#                     "logo": "https://media.api-sports.io/football/teams/663.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 663,
#                             "name": "Rabotni\u010dki",
#                             "logo": "https://media.api-sports.io/football/teams/663.png"
#                         },
#                         "start": "2022-06-01",
#                         "end": "2022-09-01"
#                     },
#                     {
#                         "team": {
#                             "id": 4332,
#                             "name": "Skopje",
#                             "logo": "https://media.api-sports.io/football/teams/4332.png"
#                         },
#                         "start": "2017-07-01",
#                         "end": "2022-06-01"
#                     },
#                     {
#                         "team": {
#                             "id": null,
#                             "name": "Vardar U19",
#                             "logo": null
#                         },
#                         "start": "2014-02-01",
#                         "end": "2017-06-01"
#                     },
#                     {
#                         "team": {
#                             "id": 4332,
#                             "name": "Skopje",
#                             "logo": "https://media.api-sports.io/football/teams/4332.png"
#                         },
#                         "start": "2009-07-01",
#                         "end": "2013-12-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 14008,
#                 "name": "B. Hristov",
#                 "firstname": "Borche",
#                 "lastname": "Hristov",
#                 "age": 54,
#                 "birth": {
#                     "date": "1970-10-02",
#                     "place": null,
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": null,
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/14008.png",
#                 "team": {
#                     "id": 663,
#                     "name": "Rabotni\u010dki",
#                     "logo": "https://media.api-sports.io/football/teams/663.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 663,
#                             "name": "Rabotni\u010dki",
#                             "logo": "https://media.api-sports.io/football/teams/663.png"
#                         },
#                         "start": "2021-11-01",
#                         "end": "2022-04-01"
#                     },
#                     {
#                         "team": {
#                             "id": 4334,
#                             "name": "Borec Veles",
#                             "logo": "https://media.api-sports.io/football/teams/4334.png"
#                         },
#                         "start": "2021-02-01",
#                         "end": "2021-10-01"
#                     },
#                     {
#                         "team": {
#                             "id": 4196,
#                             "name": "Makedonija GjP",
#                             "logo": "https://media.api-sports.io/football/teams/4196.png"
#                         },
#                         "start": "2013-07-01",
#                         "end": "2013-08-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 17115,
#                 "name": "S. Ignatov",
#                 "firstname": "Stojanche",
#                 "lastname": "Ignatov",
#                 "age": 45,
#                 "birth": {
#                     "date": "1979-12-22",
#                     "place": null,
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": null,
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/17115.png",
#                 "team": {
#                     "id": 663,
#                     "name": "Rabotni\u010dki",
#                     "logo": "https://media.api-sports.io/football/teams/663.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 663,
#                             "name": "Rabotni\u010dki",
#                             "logo": "https://media.api-sports.io/football/teams/663.png"
#                         },
#                         "start": "2022-09-01",
#                         "end": "2022-09-01"
#                     },
#                     {
#                         "team": {
#                             "id": 663,
#                             "name": "Rabotni\u010dki",
#                             "logo": "https://media.api-sports.io/football/teams/663.png"
#                         },
#                         "start": "2022-04-01",
#                         "end": "2022-06-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 18582,
#                 "name": "M. Ilievski",
#                 "firstname": "Milan",
#                 "lastname": "Ilievski",
#                 "age": 42,
#                 "birth": {
#                     "date": "1982-07-21",
#                     "place": "Skopje",
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": "182 cm",
#                 "weight": "84 kg",
#                 "photo": "https://media.api-sports.io/football/coachs/18582.png",
#                 "team": {
#                     "id": 663,
#                     "name": "Rabotni\u010dki",
#                     "logo": "https://media.api-sports.io/football/teams/663.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 663,
#                             "name": "Rabotni\u010dki",
#                             "logo": "https://media.api-sports.io/football/teams/663.png"
#                         },
#                         "start": "2022-09-01",
#                         "end": "2023-10-01"
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "get": "coachs",
#         "parameters": {
#             "team": "2265"
#         },
#         "errors": [],
#         "results": 6,
#         "paging": {
#             "current": 1,
#             "total": 1
#         },
#         "response": [
#             {
#                 "id": 4427,
#                 "name": "M. \u017di\u017eovi\u0107",
#                 "firstname": "Mladen",
#                 "lastname": "\u017di\u017eovi\u0107",
#                 "age": null,
#                 "birth": {
#                     "date": null,
#                     "place": null,
#                     "country": "Bosnia and Herzegovina"
#                 },
#                 "nationality": "Bosnia and Herzegovina",
#                 "height": null,
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/4427.png",
#                 "team": {
#                     "id": 2265,
#                     "name": "Shkupi",
#                     "logo": "https://media.api-sports.io/football/teams/2265.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 2265,
#                             "name": "Shkupi",
#                             "logo": "https://media.api-sports.io/football/teams/2265.png"
#                         },
#                         "start": "2023-09-01",
#                         "end": null
#                     },
#                     {
#                         "team": {
#                             "id": 3360,
#                             "name": "Sloboda Tuzla",
#                             "logo": "https://media.api-sports.io/football/teams/3360.png"
#                         },
#                         "start": "2021-03-01",
#                         "end": "2022-04-01"
#                     },
#                     {
#                         "team": {
#                             "id": 588,
#                             "name": "Zrinjski",
#                             "logo": "https://media.api-sports.io/football/teams/588.png"
#                         },
#                         "start": "2019-11-01",
#                         "end": "2020-12-01"
#                     },
#                     {
#                         "team": {
#                             "id": 3359,
#                             "name": "Radnik Bijeljina",
#                             "logo": "https://media.api-sports.io/football/teams/3359.png"
#                         },
#                         "start": "2017-05-01",
#                         "end": "2019-11-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 4604,
#                 "name": "T. Meglenski",
#                 "firstname": "Toni",
#                 "lastname": "Meglenski",
#                 "age": 43,
#                 "birth": {
#                     "date": "1981-05-22",
#                     "place": null,
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": null,
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/4604.png",
#                 "team": {
#                     "id": 2265,
#                     "name": "Shkupi",
#                     "logo": "https://media.api-sports.io/football/teams/2265.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 2265,
#                             "name": "Shkupi",
#                             "logo": "https://media.api-sports.io/football/teams/2265.png"
#                         },
#                         "start": "2022-09-01",
#                         "end": "2022-09-01"
#                     },
#                     {
#                         "team": {
#                             "id": 4329,
#                             "name": "Pobeda",
#                             "logo": "https://media.api-sports.io/football/teams/4329.png"
#                         },
#                         "start": "2019-03-01",
#                         "end": "2019-06-01"
# ...
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 4348,
#                             "name": "Tikvesh",
#                             "logo": "https://media.api-sports.io/football/teams/4348.png"
#                         },
#                         "start": "2021-01-01",
#                         "end": "2021-09-01"
#                     },
#                     {
#                         "team": {
#                             "id": 4334,
#                             "name": "Borec Veles",
#                             "logo": "https://media.api-sports.io/football/teams/4334.png"
#                         },
#                         "start": "2017-07-01",
#                         "end": "2018-06-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 18266,
#                 "name": "G. Mojsov",
#                 "firstname": "Gjorgi",
#                 "lastname": "Mojsov",
#                 "age": 39,
#                 "birth": {
#                     "date": "1985-05-27",
#                     "place": "Kavadarci",
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": "184 cm",
#                 "weight": "80 kg",
#                 "photo": "https://media.api-sports.io/football/coachs/18266.png",
#                 "team": {
#                     "id": 4348,
#                     "name": "Tikvesh",
#                     "logo": "https://media.api-sports.io/football/teams/4348.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 4348,
#                             "name": "Tikvesh",
#                             "logo": "https://media.api-sports.io/football/teams/4348.png"
#                         },
#                         "start": "2022-09-01",
#                         "end": null
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "get": "coachs",
#         "parameters": {
#             "team": "17663"
#         },
#         "errors": [],
#         "results": 2,
#         "paging": {
#             "current": 1,
#             "total": 1
#         },
#         "response": [
#             {
#                 "id": 4611,
#                 "name": "R. Cicmilovikj",
#                 "firstname": "Rade",
#                 "lastname": "Cicmilovikj",
#                 "age": null,
#                 "birth": {
#                     "date": null,
#                     "place": null,
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": null,
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/4611.png",
#                 "team": {
#                     "id": 17663,
#                     "name": "Voska Sport",
#                     "logo": "https://media.api-sports.io/football/teams/17663.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 17663,
#                             "name": "Voska Sport",
#                             "logo": "https://media.api-sports.io/football/teams/17663.png"
#                         },
#                         "start": "2021-11-01",
#                         "end": "2022-05-01"
#                     },
#                     {
#                         "team": {
#                             "id": 4328,
#                             "name": "Belasica",
#                             "logo": "https://media.api-sports.io/football/teams/4328.png"
#                         },
#                         "start": "2019-01-01",
#                         "end": "2019-03-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 13349,
#                 "name": "M. Radovi\u0107",
#                 "firstname": "Miljan",
#                 "lastname": "Radovi\u0107",
#                 "age": 49,
#                 "birth": {
#                     "date": "1975-10-18",
#                     "place": null,
#                     "country": "Montenegro"
#                 },
#                 "nationality": "Montenegro",
#                 "height": "180 cm",
#                 "weight": "75 kg",
#                 "photo": "https://media.api-sports.io/football/coachs/13349.png",
#                 "team": {
#                     "id": 17663,
#                     "name": "Voska Sport",
#                     "logo": "https://media.api-sports.io/football/teams/17663.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 17663,
#                             "name": "Voska Sport",
#                             "logo": "https://media.api-sports.io/football/teams/17663.png"
#                         },
#                         "start": "2023-06-01",
#                         "end": null
#                     },
#                     {
#                         "team": {
#                             "id": 3745,
#                             "name": "Decic",
#                             "logo": "https://media.api-sports.io/football/teams/3745.png"
#                         },
#                         "start": "2021-10-01",
#                         "end": "2022-04-01"
#                     },
#                     {
#                         "team": {
#                             "id": 673,
#                             "name": "Sutjeska",
#                             "logo": "https://media.api-sports.io/football/teams/673.png"
#                         },
#                         "start": "2020-11-01",
#                         "end": "2021-06-01"
#                     },
#                     {
#                         "team": {
#                             "id": 3737,
#                             "name": "Grbalj",
#                             "logo": "https://media.api-sports.io/football/teams/3737.png"
#                         },
#                         "start": "2015-03-01",
#                         "end": "2015-06-01"
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "get": "coachs",
#         "parameters": {
#             "team": "4329"
#         },
#         "errors": [],
#         "results": 1,
#         "paging": {
#             "current": 1,
#             "total": 1
#         },
#         "response": [
#             {
#                 "id": 19421,
#                 "name": "B. Dameski",
#                 "firstname": "Blagojche",
#                 "lastname": "Dameski",
#                 "age": 43,
#                 "birth": {
#                     "date": "1981-10-17",
#                     "place": null,
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": "185 cm",
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/19421.png",
#                 "team": {
#                     "id": 4329,
#                     "name": "Pobeda",
#                     "logo": "https://media.api-sports.io/football/teams/4329.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 4329,
#                             "name": "Pobeda",
#                             "logo": "https://media.api-sports.io/football/teams/4329.png"
#                         },
#                         "start": "2023-01-01",
#                         "end": null
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "get": "coachs",
#         "parameters": {
#             "team": "4338"
#         },
#         "errors": [],
#         "results": 4,
#         "paging": {
#             "current": 1,
#             "total": 1
#         },
#         "response": [
#             {
#                 "id": 2969,
#                 "name": "I. Atalan",
#                 "firstname": "Ismail",
#                 "lastname": "Atalan",
#                 "age": 44,
#                 "birth": {
#                     "date": "1980-04-01",
#                     "place": null,
#                     "country": "Germany"
#                 },
#                 "nationality": "Germany",
#                 "height": null,
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/2969.png",
#                 "team": {
#                     "id": 4338,
#                     "name": "KF Gostivari",
#                     "logo": "https://media.api-sports.io/football/teams/4338.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 4338,
#                             "name": "KF Gostivari",
#                             "logo": "https://media.api-sports.io/football/teams/4338.png"
#                         },
#                         "start": "2024-01-01",
#                         "end": null
#                     },
#                     {
#                         "team": {
#                             "id": 1316,
#                             "name": "Hallescher FC",
#                             "logo": "https://media.api-sports.io/football/teams/1316.png"
#                         },
#                         "start": "2020-02-01",
#                         "end": "2020-06-01"
#                     },
#                     {
#                         "team": {
#                             "id": 1323,
#                             "name": "Sportfreunde Lotte",
#                             "logo": "https://media.api-sports.io/football/teams/1323.png"
#                         },
#                         "start": "2019-04-01",
#                         "end": "2020-02-01"
#                     },
#                     {
#                         "team": {
#                             "id": 176,
#                             "name": "Bochum",
#                             "logo": "https://media.api-sports.io/football/teams/176.png"
#                         },
#                         "start": "2017-07-01",
#                         "end": "2017-10-01"
#                     },
#                     {
#                         "team": {
#                             "id": 1323,
#                             "name": "Sportfreunde Lotte",
#                             "logo": "https://media.api-sports.io/football/teams/1323.png"
#                         },
#                         "start": "2015-01-01",
#                         "end": "2017-07-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 4979,
#                 "name": "N. \u00d6zbayer",
#                 "firstname": "Necdet Emre",
#                 "lastname": "\u00d6zbayer",
#                 "age": 48,
#                 "birth": {
#                     "date": "1976-10-15",
#                     "place": "Eski\u015fehir",
#                     "country": "T\u00fcrkiye"
#                 },
#                 "nationality": "T\u00fcrkiye",
#                 "height": null,
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/4979.png",
#                 "team": {
#                     "id": 4338,
#                     "name": "KF Gostivari",
#                     "logo": "https://media.api-sports.io/football/teams/4338.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 4338,
#                             "name": "KF Gostivari",
#                             "logo": "https://media.api-sports.io/football/teams/4338.png"
#                         },
#                         "start": "2023-10-01",
#                         "end": "2023-11-01"
#                     },
#                     {
#                         "team": {
#                             "id": 3572,
#                             "name": "Eski\u015fehirspor",
#                             "logo": "https://media.api-sports.io/football/teams/3572.png"
#                         },
#                         "start": "2022-10-01",
#                         "end": "2023-01-01"
#                     },
#                     {
#                         "team": {
#                             "id": 7401,
#                             "name": "Erbaaspor",
#                             "logo": "https://media.api-sports.io/football/teams/7401.png"
#                         },
#                         "start": "2020-02-01",
#                         "end": "2020-07-01"
#                     },
#                     {
#                         "team": {
#                             "id": 6515,
#                             "name": "Boz\u00fcy\u00fck Vitraspor",
#                             "logo": "https://media.api-sports.io/football/teams/6515.png"
#                         },
#                         "start": "2019-08-01",
#                         "end": "2020-02-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 20426,
#                 "name": "M. Daban",
#                 "firstname": "Murat",
#                 "lastname": "Daban",
#                 "age": null,
#                 "birth": {
#                     "date": null,
#                     "place": null,
#                     "country": "T\u00fcrkiye"
#                 },
#                 "nationality": "T\u00fcrkiye",
#                 "height": null,
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/20426.png",
#                 "team": {
#                     "id": 4338,
#                     "name": "KF Gostivari",
#                     "logo": "https://media.api-sports.io/football/teams/4338.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 4338,
#                             "name": "KF Gostivari",
#                             "logo": "https://media.api-sports.io/football/teams/4338.png"
#                         },
#                         "start": "2023-07-01",
#                         "end": "2023-09-01"
#                     }
#                 ]
#             },
#             {
#                 "id": 21133,
#                 "name": "B. Panov",
#                 "firstname": "Blazho",
#                 "lastname": "Panov",
#                 "age": 51,
#                 "birth": {
#                     "date": "1973-05-23",
#                     "place": null,
#                     "country": "North Macedonia"
#                 },
#                 "nationality": "North Macedonia",
#                 "height": null,
#                 "weight": null,
#                 "photo": "https://media.api-sports.io/football/coachs/21133.png",
#                 "team": {
#                     "id": 4338,
#                     "name": "KF Gostivari",
#                     "logo": "https://media.api-sports.io/football/teams/4338.png"
#                 },
#                 "career": [
#                     {
#                         "team": {
#                             "id": 4338,
#                             "name": "KF Gostivari",
#                             "logo": "https://media.api-sports.io/football/teams/4338.png"
#                         },
#                         "start": "2023-11-01",
#                         "end": "2024-01-01"
#                     },
#                     {
#                         "team": {
#                             "id": 4338,
#                             "name": "KF Gostivari",
#                             "logo": "https://media.api-sports.io/football/teams/4338.png"
#                         },
#                         "start": "2023-09-01",
#                         "end": "2023-10-01"
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "get": "coachs",
#         "parameters": {
#             "team": "19754"
#         },
#         "errors": [],
#         "results": 0,
#         "paging": {
#             "current": 1,
#             "total": 1
#         },
#         "response": []
#     }
# ]

# %%
# Initialize an empty list to accumulate rows
rows = []

for entry in all_coach_data:
    if entry["response"]:  # Check if the response list is not empty
        coach = entry["response"][0]

        # Extracting the required fields
        firstname = coach['firstname']
        lastname = coach['lastname']
        age = coach['age']
        birth_place = coach['birth']['place']
        birth_country = coach['birth']['country']

        # Extracting the teams the coach has worked with
        for career in coach['career']:
            row = {
                'First Name': firstname,
                'Last Name': lastname,
                'Age': age,
                'Birth Place': birth_place,
                'Birth Country': birth_country,
                'Team ID': career['team']['id'],
                'Team Name': career['team']['name'],
                'Start Date': career['start'],
                'End Date': career['end']
            }
            rows.append(row)

# Create a DataFrame
df = pd.DataFrame(rows)

# %%
df.head(100)
# Out:
#    First Name Last Name   Age Birth Place    Birth Country  Team ID  \
# 0      Gorazd  Mihajlov  51.0        None  North Macedonia    574.0
# 1      Gorazd  Mihajlov  51.0        None  North Macedonia   4331.0
# 2      Gorazd  Mihajlov  51.0        None  North Macedonia   4334.0
# 3      Gorazd  Mihajlov  51.0        None  North Macedonia   4347.0
# 4      Gorazd  Mihajlov  51.0        None  North Macedonia      NaN
# ..        ...       ...   ...         ...              ...      ...
# 79     Ismail    Atalan  44.0        None          Germany   4338.0
# 80     Ismail    Atalan  44.0        None          Germany   1316.0
# 81     Ismail    Atalan  44.0        None          Germany   1323.0
# 82     Ismail    Atalan  44.0        None          Germany    176.0
# 83     Ismail    Atalan  44.0        None          Germany   1323.0
#
#              Team Name  Start Date    End Date
# 0        Vardar Skopje  2023-12-01        None
# 1               Sileks  2021-06-01  2023-12-01
# 2          Borec Veles  2018-07-01  2021-01-01
# 3               Teteks  2015-01-01  2016-06-01
# 4             Napredok  2013-08-01  2014-01-01
# ..                 ...         ...         ...
# 79        KF Gostivari  2024-01-01        None
# 80       Hallescher FC  2020-02-01  2020-06-01
# 81  Sportfreunde Lotte  2019-04-01  2020-02-01
# 82              Bochum  2017-07-01  2017-10-01
# 83  Sportfreunde Lotte  2015-01-01  2017-07-01
#
# [84 rows x 9 columns]

# %%
# Convert 'Start Date' and 'End Date' columns to datetime format
df['Start Date'] = pd.to_datetime(df['Start Date'], format='%Y-%m-%d', errors='coerce')
df['End Date'] = pd.to_datetime(df['End Date'], format='%Y-%m-%d', errors='coerce')

# Handle NaN values before converting to integers
df['Age'] = df['Age'].fillna(0).astype(int)

# Define dictionary with column names and desired data types
dtypes_dict = {
    'First Name': str,
    'Last Name': str,
    'Age': int,
    'Birth Place': str,
    'Birth Country': str,
    'Team ID': float,
    'Team Name': str,
}

# Change data types of columns
coach_df =df.astype(dtypes_dict)

# %%
coach_filtered_df = coach_df[coach_df['Team ID'].isin(all_team_ids)]

# %%
#Converting First Macedonia League data to Csv
coach_filtered_df.to_csv('First_Macedonia_League_Coach_Data_Raw.csv', index=False)
